# %%
from firedrake import *
from irksome import RadauIIA, Dt, MeshConstant, TimeStepper, PEPRK, GaussLegendre, ContinuousPetrovGalerkinScheme
from scipy.io import loadmat
from scipy.interpolate import RegularGridInterpolator
# Out:
# firedrake:WARNING OMP_NUM_THREADS is not set or is set to a value greater than 1, we suggest setting OMP_NUM_THREADS=1 to improve performance

# %%
from firedrake import *
from irksome import RadauIIA, Dt, MeshConstant, TimeStepper, PEPRK, GaussLegendre, ContinuousPetrovGalerkinScheme
from scipy.io import loadmat
from scipy.interpolate import RegularGridInterpolator

butcher_tableau = ContinuousPetrovGalerkinScheme(2)

Nx = 20
Ny = 20
L = 0.5
h = 1
msh_p = PeriodicRectangleMesh(Nx, Ny, L, h, direction='x')#, quadrilateral=True)
V = VectorFunctionSpace(msh_p, "CG", 2, dim=2)
W = FunctionSpace(msh_p, "CG", 1)
Z = V*W

MC = MeshConstant(msh_p)
# dt = 0.002
dt = MC.Constant(0.1)
Re = MC.Constant(90.0)

# %%
# Poiseuille laminar flow in [0, 2]
u0 = Function(V)
x, y = SpatialCoordinate(msh_p)
psi = sin(pi*y)

u0.assign(project(as_vector([psi, 0]), V))
p0 = Function(W)

# %%
t = MC.Constant(0.0)
# Initialize solution function
up = Function(Z)
u_, p_ = up.subfunctions
u_.rename('Velocity')
p_.rename("Pressure")

# Assign initial conditions
u_.assign(u0)
p_.assign(p0)

# Set up variational problem
dx_p = dx(msh_p)

u, p = split(up)
v, w = TestFunctions(Z)
F = (inner(Dt(u), v) * dx_p + inner(dot(grad(u), u), v) * dx_p
     + 1/Re * inner(grad(u), grad(v)) * dx_p - inner(p, div(v)) * dx_p
     + inner(div(u), w) * dx_p)

bcs = [DirichletBC(Z.sub(0), as_vector([0, 0]), (1, 2))]
u_exact = Function(V)
psi = sin(pi*y)*exp(-pi*pi*t/Re)
u_exact.assign(project(as_vector([psi, 0]), V))
error = u_ - u_exact
E = inner(error, error)*dx_p

# Solver parameters
luparams = {"mat_type": "aij",
            "snes_type": "newtonls",
            "snes_monitor": None,
            "ksp_type": "preonly",
            "pc_type": "lu",
            "pc_factor_mat_solver_type": "mumps",
            "snes_linesearch_type": "l2",
            "snes_force_iteration": 1,
            "snes_rtol": 1e-8,
            "snes_atol": 1e-8
            }

# Define nullspace for pressure
nsp = MixedVectorSpaceBasis(Z, [Z.sub(0), VectorSpaceBasis(constant=True, comm=msh_p.comm)])

stepper = TimeStepper(F, butcher_tableau, t, dt, up, bcs=bcs,
                      solver_parameters=luparams, nullspace=nsp)

errors = []
times = [float(t)]
# out = File("ns_Poiseuille_Re300.pvd")
# out.write(u_, p_, time=float(t))


et = assemble(E)

print(f"  Error = {et}")
errors.append(et)

# Time stepping loop
for _ in range(100):
     print(f"Stepping from time {float(t)}")
     stepper.advance()
     t.assign(float(t) + float(dt))
     u_exact = Function(V)
     psi = sin(pi*y)*exp(-pi*pi*t/Re)
     u_exact.assign(project(as_vector([psi, 0]), V))
     error = u_ - u_exact
     E = inner(error, error)*dx_p
     et = assemble(E)
     print(f"  Error = {et}")
     errors.append(et)
     times.append(float(t))
# Out:
#   Error = 9.859221111133075e-34
# Stepping from time 0.0
#   0 SNES Function norm 7.900124817919e-05
#   1 SNES Function norm 2.336554013141e-11
#   Error = 2.112535641277595e-11
# Stepping from time 0.1
#   0 SNES Function norm 9.433664422289e-05
#   1 SNES Function norm 1.560212230587e-12
#   Error = 1.3014801873347074e-11
# Stepping from time 0.2
#   0 SNES Function norm 9.330678313273e-05
#   1 SNES Function norm 7.622681734317e-13
#   Error = 1.2211563533728543e-11
# Stepping from time 0.30000000000000004
#   0 SNES Function norm 9.228848978182e-05
#   1 SNES Function norm 4.969209954790e-13
#   Error = 1.188047172052599e-11
# Stepping from time 0.4
#   0 SNES Function norm 9.128152569166e-05
#   1 SNES Function norm 3.987932147155e-13
#   Error = 1.1625514845847575e-11
# Stepping from time 0.5
#   0 SNES Function norm 9.028568665225e-05
#   1 SNES Function norm 3.388049151455e-13
#   Error = 1.1385257264463206e-11
# Stepping from time 0.6
#   0 SNES Function norm 8.930080075143e-05
#   1 SNES Function norm 2.944697021222e-13
#   Error = 1.1148078466867113e-11
# Stepping from time 0.7
#   0 SNES Function norm 8.832671630729e-05
#   1 SNES Function norm 2.562838214012e-13
#   Error = 1.0912587530871184e-11
# Stepping from time 0.7999999999999999
#   0 SNES Function norm 8.736329491628e-05
#   1 SNES Function norm 2.248394202402e-13
#   Error = 1.0679466363593777e-11
# Stepping from time 0.8999999999999999
#   0 SNES Function norm 8.641040707841e-05
#   1 SNES Function norm 1.977125166962e-13
#   Error = 1.0449575046966055e-11
# Stepping from time 0.9999999999999999
#   0 SNES Function norm 8.546792940930e-05
#   1 SNES Function norm 1.741683755924e-13
#   Error = 1.0223555448117433e-11
# Stepping from time 1.0999999999999999
#   0 SNES Function norm 8.453574287030e-05
#   1 SNES Function norm 1.535681634578e-13
#   Error = 1.0001808186954518e-11
# Stepping from time 1.2
#   0 SNES Function norm 8.361373163679e-05
#   1 SNES Function norm 1.360216102294e-13
#   Error = 9.784548963735578e-12
# Stepping from time 1.3
#   0 SNES Function norm 8.270178237009e-05
#   1 SNES Function norm 1.242973125034e-13
#   Error = 9.571867650982432e-12
# Stepping from time 1.4000000000000001
#   0 SNES Function norm 8.179978376582e-05
#   1 SNES Function norm 1.058865339433e-13
#   Error = 9.363773342584165e-12
# Stepping from time 1.5000000000000002
#   0 SNES Function norm 8.090762621583e-05
#   1 SNES Function norm 9.852315036093e-14
#   Error = 9.16022574958489e-12
# Stepping from time 1.6000000000000003
#   0 SNES Function norm 8.002520167071e-05
#   1 SNES Function norm 8.311812809713e-14
#   Error = 8.961155232149099e-12
# Stepping from time 1.7000000000000004
#   0 SNES Function norm 7.915240343397e-05
#   1 SNES Function norm 7.369836168696e-14
#   Error = 8.766476271922633e-12
# Stepping from time 1.8000000000000005
#   0 SNES Function norm 7.828912615375e-05
#   1 SNES Function norm 6.547494963888e-14
#   Error = 8.576095166496103e-12
# Stepping from time 1.9000000000000006
#   0 SNES Function norm 7.743526569827e-05
#   1 SNES Function norm 5.839879856738e-14
#   Error = 8.389914987732901e-12
# Stepping from time 2.0000000000000004
#   0 SNES Function norm 7.659071914157e-05
#   1 SNES Function norm 5.198747684334e-14
#   Error = 8.207838479675055e-12
# Stepping from time 2.1000000000000005
#   0 SNES Function norm 7.575538472769e-05
#   1 SNES Function norm 4.688972315041e-14
#   Error = 8.029769632159242e-12
# Stepping from time 2.2000000000000006
#   0 SNES Function norm 7.492916183799e-05
#   1 SNES Function norm 4.164942470597e-14
#   Error = 7.855614575012182e-12
# Stepping from time 2.3000000000000007
#   0 SNES Function norm 7.411195097937e-05
#   1 SNES Function norm 3.746799884228e-14
#   Error = 7.685281976731941e-12
# Stepping from time 2.400000000000001
#   0 SNES Function norm 7.330365375812e-05
#   1 SNES Function norm 3.386168185736e-14
#   Error = 7.51868319810326e-12
# Stepping from time 2.500000000000001
#   0 SNES Function norm 7.250417287103e-05
#   1 SNES Function norm 3.148595151706e-14
#   Error = 7.355732245584102e-12
# Stepping from time 2.600000000000001
#   0 SNES Function norm 7.171341208378e-05
#   1 SNES Function norm 2.799517142801e-14
#   Error = 7.196345694000897e-12
# Stepping from time 2.700000000000001
#   0 SNES Function norm 7.093127622048e-05
#   1 SNES Function norm 2.646249154476e-14
#   Error = 7.040442605716579e-12
# Stepping from time 2.800000000000001
#   0 SNES Function norm 7.015767115519e-05
#   1 SNES Function norm 2.322791969218e-14
#   Error = 6.8879443903934305e-12
# Stepping from time 2.9000000000000012
#   0 SNES Function norm 6.939250379452e-05
#   1 SNES Function norm 2.170206752391e-14
#   Error = 6.738774598605965e-12
# Stepping from time 3.0000000000000013
#   0 SNES Function norm 6.863568206138e-05
#   1 SNES Function norm 2.412255892519e-14
#   Error = 6.592858861846592e-12
# Stepping from time 3.1000000000000014
#   0 SNES Function norm 6.788711489075e-05
#   1 SNES Function norm 1.855296744360e-14
#   Error = 6.450124790778306e-12
# Stepping from time 3.2000000000000015
#   0 SNES Function norm 6.714671221850e-05
#   1 SNES Function norm 1.777932572095e-14
#   Error = 6.3105018217154775e-12
# Stepping from time 3.3000000000000016
#   0 SNES Function norm 6.641438496143e-05
#   1 SNES Function norm 1.637202372048e-14
#   Error = 6.1739211480912136e-12
# Stepping from time 3.4000000000000017
#   0 SNES Function norm 6.569004501404e-05
#   1 SNES Function norm 1.546576954505e-14
#   Error = 6.040315655586785e-12
# Stepping from time 3.5000000000000018
#   0 SNES Function norm 6.497360523521e-05
#   1 SNES Function norm 1.548755193547e-14
#   Error = 5.9096198360069886e-12
# Stepping from time 3.600000000000002
#   0 SNES Function norm 6.426497943670e-05
#   1 SNES Function norm 1.401145468594e-14
#   Error = 5.78176969969949e-12
# Stepping from time 3.700000000000002
#   0 SNES Function norm 6.356408237046e-05
#   1 SNES Function norm 1.343841402792e-14
#   Error = 5.656702769578197e-12
# Stepping from time 3.800000000000002
#   0 SNES Function norm 6.287082972485e-05
#   1 SNES Function norm 1.697946036500e-14
#   Error = 5.534358002796599e-12
# Stepping from time 3.900000000000002
#   0 SNES Function norm 6.218513810783e-05
#   1 SNES Function norm 1.264603319723e-14
#   Error = 5.414675731588501e-12
# Stepping from time 4.000000000000002
#   0 SNES Function norm 6.150692503680e-05
#   1 SNES Function norm 1.597347911582e-14
#   Error = 5.2975976715509935e-12
# Stepping from time 4.100000000000001
#   0 SNES Function norm 6.083610893588e-05
#   1 SNES Function norm 1.168033999162e-14
#   Error = 5.183066765548282e-12
# Stepping from time 4.200000000000001
#   0 SNES Function norm 6.017260911063e-05
#   1 SNES Function norm 2.059060297978e-14
#   Error = 5.071027337573647e-12
# Stepping from time 4.300000000000001
#   0 SNES Function norm 5.951634576174e-05
#   1 SNES Function norm 1.100879756164e-14
#   Error = 4.961424820954255e-12
# Stepping from time 4.4
#   0 SNES Function norm 5.886723994505e-05
#   1 SNES Function norm 1.082885731009e-14
#   Error = 4.854205967136095e-12
# Stepping from time 4.5
#   0 SNES Function norm 5.822521359496e-05
#   1 SNES Function norm 1.052816522087e-14
#   Error = 4.749318655562276e-12
# Stepping from time 4.6
#   0 SNES Function norm 5.759018948772e-05
#   1 SNES Function norm 1.143880519211e-14
#   Error = 4.646711923400098e-12
# Stepping from time 4.699999999999999
#   0 SNES Function norm 5.696209124654e-05
#   1 SNES Function norm 1.751674608186e-13
#   Error = 4.546336263872967e-12
# Stepping from time 4.799999999999999
#   0 SNES Function norm 5.634084335749e-05
#   1 SNES Function norm 9.728940612961e-15
#   Error = 4.44814218701585e-12
# Stepping from time 4.899999999999999
#   0 SNES Function norm 5.572637100802e-05
#   1 SNES Function norm 9.556408302752e-15
#   Error = 4.352082441120414e-12
# Stepping from time 4.999999999999998
#   0 SNES Function norm 5.511860039135e-05
#   1 SNES Function norm 9.316464372122e-15
#   Error = 4.258110371617637e-12
# Stepping from time 5.099999999999998
#   0 SNES Function norm 5.451745837628e-05
#   1 SNES Function norm 9.450430602843e-15
#   Error = 4.1661803614084796e-12
# Stepping from time 5.1999999999999975
#   0 SNES Function norm 5.392287266453e-05
#   1 SNES Function norm 9.184796692939e-15
#   Error = 4.0762478085842616e-12
# Stepping from time 5.299999999999997
#   0 SNES Function norm 5.333477174708e-05
#   1 SNES Function norm 8.840014270989e-15
#   Error = 3.988269066622149e-12
# Stepping from time 5.399999999999997
#   0 SNES Function norm 5.275308489271e-05
#   1 SNES Function norm 8.493863530244e-15
#   Error = 3.902201445702819e-12
# Stepping from time 5.4999999999999964
#   0 SNES Function norm 5.217774214362e-05
#   1 SNES Function norm 9.377903379493e-15
#   Error = 3.818003197320148e-12
# Stepping from time 5.599999999999996
#   0 SNES Function norm 5.160867430547e-05
#   1 SNES Function norm 8.180455588884e-15
#   Error = 3.735633510570135e-12
# Stepping from time 5.699999999999996
#   0 SNES Function norm 5.104581294065e-05
#   1 SNES Function norm 8.021266950072e-15
#   Error = 3.655052430114479e-12
# Stepping from time 5.799999999999995
#   0 SNES Function norm 5.048909035354e-05
#   1 SNES Function norm 7.804124780702e-15
#   Error = 3.5762209007401606e-12
# Stepping from time 5.899999999999995
#   0 SNES Function norm 4.993843959171e-05
#   1 SNES Function norm 4.992139686314e-14
#   Error = 3.4991007269963656e-12
# Stepping from time 5.999999999999995
#   0 SNES Function norm 4.939379443215e-05
#   1 SNES Function norm 7.536996900310e-15
#   Error = 3.4236545113544094e-12
# Stepping from time 6.099999999999994
#   0 SNES Function norm 4.885508936924e-05
#   1 SNES Function norm 7.348985093041e-15
#   Error = 3.349845712488146e-12
# Stepping from time 6.199999999999994
#   0 SNES Function norm 4.832225962078e-05
#   1 SNES Function norm 7.354022269619e-15
#   Error = 3.2776385878212132e-12
# Stepping from time 6.299999999999994
#   0 SNES Function norm 4.779524110604e-05
#   1 SNES Function norm 7.004392708937e-15
#   Error = 3.2069981602985522e-12
# Stepping from time 6.399999999999993
#   0 SNES Function norm 4.727397044282e-05
#   1 SNES Function norm 7.950828640170e-15
#   Error = 3.1378902319599225e-12
# Stepping from time 6.499999999999993
#   0 SNES Function norm 4.675838494263e-05
#   1 SNES Function norm 6.894349811520e-15
#   Error = 3.0702813525046367e-12
# Stepping from time 6.5999999999999925
#   0 SNES Function norm 4.624842259965e-05
#   1 SNES Function norm 8.148748890259e-15
#   Error = 3.0041388075221e-12
# Stepping from time 6.699999999999992
#   0 SNES Function norm 4.574402208499e-05
#   1 SNES Function norm 9.189060595897e-15
#   Error = 2.9394305804650067e-12
# Stepping from time 6.799999999999992
#   0 SNES Function norm 4.524512273698e-05
#   1 SNES Function norm 1.016093971239e-14
#   Error = 2.876125406529754e-12
# Stepping from time 6.8999999999999915
#   0 SNES Function norm 4.475166456039e-05
#   1 SNES Function norm 8.340924180768e-15
#   Error = 2.814192649659951e-12
# Stepping from time 6.999999999999991
#   0 SNES Function norm 4.426358820775e-05
#   1 SNES Function norm 6.126340759807e-15
#   Error = 2.7536023641450183e-12
# Stepping from time 7.099999999999991
#   0 SNES Function norm 4.378083498308e-05
#   1 SNES Function norm 5.912509904620e-15
#   Error = 2.694325269403409e-12
# Stepping from time 7.19999999999999
#   0 SNES Function norm 4.330334683046e-05
#   1 SNES Function norm 5.770114098968e-15
#   Error = 2.6363327251111297e-12
# Stepping from time 7.29999999999999
#   0 SNES Function norm 4.283106632657e-05
#   1 SNES Function norm 5.709625108780e-15
#   Error = 2.579596711931036e-12
# Stepping from time 7.39999999999999
#   0 SNES Function norm 4.236393667404e-05
#   1 SNES Function norm 5.543580715964e-15
#   Error = 2.5240898320311377e-12
# Stepping from time 7.499999999999989
#   0 SNES Function norm 4.190190169588e-05
#   1 SNES Function norm 5.520543320799e-15
#   Error = 2.469785278642898e-12
# Stepping from time 7.599999999999989
#   0 SNES Function norm 4.144490582677e-05
#   1 SNES Function norm 5.311672737380e-15
#   Error = 2.416656844828853e-12
# Stepping from time 7.699999999999989
#   0 SNES Function norm 4.099289410883e-05
#   1 SNES Function norm 5.198453035949e-15
#   Error = 2.3646788919945987e-12
# Stepping from time 7.799999999999988
#   0 SNES Function norm 4.054581218247e-05
#   1 SNES Function norm 7.450098536568e-15
#   Error = 2.313826329975753e-12
# Stepping from time 7.899999999999988
#   0 SNES Function norm 4.010360628057e-05
#   1 SNES Function norm 5.031485533558e-15
#   Error = 2.264074661792148e-12
# Stepping from time 7.999999999999988
#   0 SNES Function norm 3.966622322592e-05
#   1 SNES Function norm 4.909403682065e-15
#   Error = 2.2153998778436942e-12
# Stepping from time 8.099999999999987
#   0 SNES Function norm 3.923361041558e-05
#   1 SNES Function norm 4.901105148333e-15
#   Error = 2.167778521153332e-12
# Stepping from time 8.199999999999987
#   0 SNES Function norm 3.880571582507e-05
#   1 SNES Function norm 5.699321788143e-15
#   Error = 2.1211876316094534e-12
# Stepping from time 8.299999999999986
#   0 SNES Function norm 3.838248799451e-05
#   1 SNES Function norm 4.577402980020e-15
#   Error = 2.075604779993397e-12
# Stepping from time 8.399999999999986
#   0 SNES Function norm 3.796387602837e-05
#   1 SNES Function norm 4.478233776242e-15
#   Error = 2.0310080078670094e-12
# Stepping from time 8.499999999999986
#   0 SNES Function norm 3.754982958288e-05
#   1 SNES Function norm 4.843249745075e-15
#   Error = 1.9873758357224737e-12
# Stepping from time 8.599999999999985
#   0 SNES Function norm 3.714029886461e-05
#   1 SNES Function norm 4.246283081336e-15
#   Error = 1.9446872669114765e-12
# Stepping from time 8.699999999999985
#   0 SNES Function norm 3.673523462430e-05
#   1 SNES Function norm 4.215086211713e-15
#   Error = 1.90292175411943e-12
# Stepping from time 8.799999999999985
#   0 SNES Function norm 3.633458814810e-05
#   1 SNES Function norm 4.229044650407e-15
#   Error = 1.862059210916692e-12
# Stepping from time 8.899999999999984
#   0 SNES Function norm 3.593831125505e-05
#   1 SNES Function norm 4.462698567374e-15
#   Error = 1.8220799774745607e-12
# Stepping from time 8.999999999999984
#   0 SNES Function norm 3.554635628797e-05
#   1 SNES Function norm 3.900596047616e-15
#   Error = 1.7829648385026718e-12
# Stepping from time 9.099999999999984
#   0 SNES Function norm 3.515867611137e-05
#   1 SNES Function norm 3.825650187638e-15
#   Error = 1.7446949913537555e-12
# Stepping from time 9.199999999999983
#   0 SNES Function norm 3.477522410239e-05
#   1 SNES Function norm 3.758116501519e-15
#   Error = 1.7072520475547713e-12
# Stepping from time 9.299999999999983
#   0 SNES Function norm 3.439595414725e-05
#   1 SNES Function norm 3.707544879238e-15
#   Error = 1.67061801640721e-12
# Stepping from time 9.399999999999983
#   0 SNES Function norm 3.402082063472e-05
#   1 SNES Function norm 3.606463343867e-15
#   Error = 1.6347753095019222e-12
# Stepping from time 9.499999999999982
#   0 SNES Function norm 3.364977845184e-05
#   1 SNES Function norm 4.075620707622e-15
#   Error = 1.5997067134669454e-12
# Stepping from time 9.599999999999982
#   0 SNES Function norm 3.328278297655e-05
#   1 SNES Function norm 3.698265615746e-15
#   Error = 1.5653954035775559e-12
# Stepping from time 9.699999999999982
#   0 SNES Function norm 3.291979007480e-05
#   1 SNES Function norm 3.369568811782e-15
#   Error = 1.5318249169357686e-12
# Stepping from time 9.799999999999981
#   0 SNES Function norm 3.256075609281e-05
#   1 SNES Function norm 3.294108582067e-15
#   Error = 1.4989791483014384e-12
# Stepping from time 9.89999999999998
#   0 SNES Function norm 3.220563785303e-05
#   1 SNES Function norm 3.411751209950e-15
#   Error = 1.4668423484280797e-12

# %%
np.savez('errors_N20', errors=errors, times=times)

# %%
error_N = []

data = np.load('errors_N3.npz')
errors = data['errors']
error_N.append(np.sum(errors)/len(errors))

data = np.load('errors_N10.npz')
errors = data['errors']
error_N.append(np.sum(errors)/len(errors))

data = np.load('errors_N20.npz')
errors = data['errors']
error_N.append(np.sum(errors)/len(errors))

data = np.load('errors_N50.npz')
errors = data['errors']
error_N.append(np.sum(errors)/len(errors))

# %%
np.savez('errors', error_N=error_N, N=[3,10,20,50])

# %%
plt.loglog([3, 10, 20, 50], error_N, '-o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.loglog([3, 10, 20, 50], error_N, '-o')
#
# NameError: name 'plt' is not defined

# %%
# slope value
np.polyfit(np.log([1/3, 1/10, 1/20, 1/50]), np.log(error_N), 1)
# Out:
# array([ 6.87080976, -5.39747153])
